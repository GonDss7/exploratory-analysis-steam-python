# %% [markdown]
# <a href="https://colab.research.google.com/github/GonDss7/exploratory-analysis-steam-python/blob/main/Premier_League_raw_core.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lo primero que hago es llamar a las librerías, que se presenten

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Ahora, voy a ir tabla por tabla, realizando un proceso de limpieza, data mining, ordenarlos, homogeneizarlos, empaquetarlos y dejarlos listos :

# %%
team_stats = pd.read_csv('team_stats.csv')
display(team_stats)
# Out:
#                team  players   age  possession  goals  assists  penalty_kicks  \
# 0           Arsenal       25  26.6        56.8     65       53              2
# 1       Aston Villa       28  27.8        51.0     56       45              3
# 2       Bournemouth       29  25.9        48.1     55       39              6
# 3         Brentford       28  26.6        47.8     64       43              5
# 4          Brighton       32  25.7        52.0     60       40              6
# 5           Chelsea       29  24.5        57.3     60       46              4
# 6    Crystal Palace       29  27.0        43.1     48       37              3
# 7           Everton       26  28.8        41.1     38       26              2
# 8            Fulham       26  28.8        52.4     53       44              3
# 9      Ipswich Town       32  26.6        40.5     34       25              2
# 10   Leicester City       31  27.4        45.6     33       25              2
# 11        Liverpool       24  28.0        57.4     84       64              9
# 12  Manchester City       29  27.6        61.6     69       51              2
# 13   Manchester Utd       31  26.3        53.2     40       28              3
# 14    Newcastle Utd       24  28.2        50.9     66       50              5
# 15  Nott'ham Forest       23  27.0        40.9     57       42              3
# 16      Southampton       36  26.1        48.8     24       15              0
# 17        Tottenham       31  25.8        55.2     60       47              2
# 18         West Ham       27  29.0        48.2     40       26              3
# 19           Wolves       31  27.7        48.1     52       41              0
#
#     penalty_kick_attempts  yellows  reds  expected_goals  expected_assists  \
# 0                       2       70     6            57.6              43.2
# 1                       6       74     3            55.7              41.5
# 2                       7       97     3            62.4              42.6
# 3                       6       61     1            57.6              41.3
# 4                       6       77     3            56.5              39.7
# 5                       5       99     2            66.7              51.6
# 6                       4       80     4            58.7              44.7
# 7                       2       78     2            40.6              31.5
# 8                       4       80     2            47.8              36.9
# 9                       2       91     5            33.6              23.7
# 10                      3       85     0            32.4              25.0
# 11                      9       65     2            80.0              59.6
# 12                      3       59     2            65.2              52.5
# 13                      3       84     3            49.7              37.9
# 14                      6       67     1            62.6              45.2
# 15                      3       88     2            44.3              32.1
# 16                      2       89     3            32.0              24.5
# 17                      3       69     1            56.8              43.1
# 18                      3       81     3            45.9              33.0
# 19                      0       77     2            42.6              34.6
#
#     progressive_carries  progressive_passes
# 0                   830                1764
# 1                   709                1326
# 2                   732                1438
# 3                   579                1318
# 4                   798                1478
# 5                   848                1573
# 6                   491                1140
# 7                   474                1027
# 8                   773                1524
# 9                   488                 896
# 10                  569                1068
# 11                  801                1846
# 12                 1112                1890
# 13                  669                1379
# 14                  727                1541
# 15                  610                1079
# 16                  628                1114
# 17                  827                1582
# 18                  617                1192
# 19                  587                1148

# %%
# Drop the last 4 columns
team_stats = team_stats.drop(team_stats.columns[-4:], axis=1)

# Display the updated DataFrame
display(team_stats)
# Out:
#                team  players   age  possession  goals  assists  penalty_kicks  \
# 0           Arsenal       25  26.6        56.8     65       53              2
# 1       Aston Villa       28  27.8        51.0     56       45              3
# 2       Bournemouth       29  25.9        48.1     55       39              6
# 3         Brentford       28  26.6        47.8     64       43              5
# 4          Brighton       32  25.7        52.0     60       40              6
# 5           Chelsea       29  24.5        57.3     60       46              4
# 6    Crystal Palace       29  27.0        43.1     48       37              3
# 7           Everton       26  28.8        41.1     38       26              2
# 8            Fulham       26  28.8        52.4     53       44              3
# 9      Ipswich Town       32  26.6        40.5     34       25              2
# 10   Leicester City       31  27.4        45.6     33       25              2
# 11        Liverpool       24  28.0        57.4     84       64              9
# 12  Manchester City       29  27.6        61.6     69       51              2
# 13   Manchester Utd       31  26.3        53.2     40       28              3
# 14    Newcastle Utd       24  28.2        50.9     66       50              5
# 15  Nott'ham Forest       23  27.0        40.9     57       42              3
# 16      Southampton       36  26.1        48.8     24       15              0
# 17        Tottenham       31  25.8        55.2     60       47              2
# 18         West Ham       27  29.0        48.2     40       26              3
# 19           Wolves       31  27.7        48.1     52       41              0
#
#     penalty_kick_attempts  yellows  reds
# 0                       2       70     6
# 1                       6       74     3
# 2                       7       97     3
# 3                       6       61     1
# 4                       6       77     3
# 5                       5       99     2
# 6                       4       80     4
# 7                       2       78     2
# 8                       4       80     2
# 9                       2       91     5
# 10                      3       85     0
# 11                      9       65     2
# 12                      3       59     2
# 13                      3       84     3
# 14                      6       67     1
# 15                      3       88     2
# 16                      2       89     3
# 17                      3       69     1
# 18                      3       81     3
# 19                      0       77     2

# %%
team_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   team                   20 non-null     object
#  1   players                20 non-null     int64
#  2   age                    20 non-null     float64
#  3   possession             20 non-null     float64
#  4   goals                  20 non-null     int64
#  5   assists                20 non-null     int64
#  6   penalty_kicks          20 non-null     int64
#  7   penalty_kick_attempts  20 non-null     int64
#  8   yellows                20 non-null     int64
#  9   reds                   20 non-null     int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 1.7+ KB

# %%
# Check for null values in each column
null_values = team_stats.isnull().sum()

# Display the count of null values per column
display(null_values)
# Out:
# team                     0
# players                  0
# age                      0
# possession               0
# goals                    0
# assists                  0
# penalty_kicks            0
# penalty_kick_attempts    0
# yellows                  0
# reds                     0
# dtype: int64

# %%
team_salary = pd.read_csv('team_salary.csv')
display(team_salary)
# Out:
#                team  players   weekly     annual
# 0   Manchester City       61  5211401  270992872
# 1    Manchester Utd       60  4668844  242779887
# 2           Chelsea       71  4443518  231062958
# 3           Arsenal       51  4373711  227432965
# 4         Liverpool       60  3325255  172913278
# 5       Aston Villa       68  2776192  144361995
# 6         Tottenham       66  2705714  140697102
# 7     Newcastle Utd       62  2666111  138637776
# 8          West Ham       54  2329155  121116085
# 9           Everton       54  1843859   95880658
# 10   Crystal Palace       63  1802243   93716625
# 11           Fulham       53  1765997   91831819
# 12   Leicester City       57  1688806   87817887
# 13  Nott'ham Forest       62  1639135   85235009
# 14         Brighton       71  1599532   83175683
# 15      Southampton       68  1446493   75217626
# 16      Bournemouth       56  1412260   73437533
# 17           Wolves       70  1374000   71448017
# 18        Brentford       57  1070606   55671515
# 19     Ipswich Town       56   883334   45933362

# %%
team_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   team     20 non-null     object
#  1   players  20 non-null     int64
#  2   weekly   20 non-null     int64
#  3   annual   20 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 772.0+ bytes

# %%
# Check for null values in each column
null_values = team_salary.isnull().sum()

# Display the count of null values per column
display(null_values)
# Out:
# team       0
# players    0
# weekly     0
# annual     0
# dtype: int64

# %%
team_possession_stats = pd.read_csv('team_possession_stats.csv')
display(team_possession_stats)
# Out:
#                team  possession  touches  deffensive_touches  middle_touches  \
# 0           Arsenal        56.8    23363                5960           10107
# 1       Aston Villa        51.0    21291                7113            9119
# 2       Bournemouth        48.1    20971                6300            9029
# 3         Brentford        47.8    20864                8064            7830
# 4          Brighton        52.0    22986                7355            9983
# 5           Chelsea        57.3    24671                7379           11139
# 6    Crystal Palace        43.1    19925                7445            8276
# 7           Everton        41.1    18989                6745            7761
# 8            Fulham        52.4    23328                7797            9590
# 9      Ipswich Town        40.5    18531                7601            7286
# 10   Leicester City        45.6    21309                7855            9685
# 11        Liverpool        57.4    25092                7133           11187
# 12  Manchester City        61.6    27459                6350           11762
# 13   Manchester Utd        53.2    23978                8418           10137
# 14    Newcastle Utd        50.9    22350                7319            9347
# 15  Nott'ham Forest        40.9    18416                6288            7448
# 16      Southampton        48.8    22284                8220            9579
# 17        Tottenham        55.2    23886                7914           10033
# 18         West Ham        48.2    22119                8082            9479
# 19           Wolves        48.1    21741                7610            9835
#
#     attacking_touches  attempted_take_ons  successful_take_ons  carries  \
# 0                7471                 706                  310    13816
# 1                5275                 706                  317    12118
# 2                5902                 651                  284    11283
# 3                5166                 609                  262    11008
# 4                5913                 777                  328    13554
# 5                6367                 769                  322    14242
# 6                4393                 479                  200    10028
# 7                4689                 622                  274     9338
# 8                6184                 623                  281    13741
# 9                3850                 626                  270     9052
# 10               3976                 627                  259    12065
# 11               6995                 661                  295    14444
# 12               9571                 780                  370    17678
# 13               5646                 614                  252    14601
# 14               5905                 644                  277    12632
# 15               4910                 570                  257     8513
# 16               4682                 715                  298    12454
# 17               6174                 798                  303    14833
# 18               4769                 776                  334    11298
# 19               4559                 704                  310    12101
#
#     total_distance_carried
# 0                    73408
# 1                    67517
# 2                    66571
# 3                    60063
# 4                    74918
# 5                    76825
# 6                    50667
# 7                    49840
# 8                    72323
# 9                    51629
# 10                   60544
# 11                   73791
# 12                  101274
# 13                   72739
# 14                   68484
# 15                   48176
# 16                   65799
# 17                   81603
# 18                   57335
# 19                   65076

# %%
# Drop the last 7 columns from team_possession_stats
team_possession_stats = team_possession_stats.drop(team_possession_stats.columns[-7:], axis=1)

# Display the updated DataFrame
display(team_possession_stats)
# Out:
#                team  possession  touches
# 0           Arsenal        56.8    23363
# 1       Aston Villa        51.0    21291
# 2       Bournemouth        48.1    20971
# 3         Brentford        47.8    20864
# 4          Brighton        52.0    22986
# 5           Chelsea        57.3    24671
# 6    Crystal Palace        43.1    19925
# 7           Everton        41.1    18989
# 8            Fulham        52.4    23328
# 9      Ipswich Town        40.5    18531
# 10   Leicester City        45.6    21309
# 11        Liverpool        57.4    25092
# 12  Manchester City        61.6    27459
# 13   Manchester Utd        53.2    23978
# 14    Newcastle Utd        50.9    22350
# 15  Nott'ham Forest        40.9    18416
# 16      Southampton        48.8    22284
# 17        Tottenham        55.2    23886
# 18         West Ham        48.2    22119
# 19           Wolves        48.1    21741

# %%
# Check for null values in each column
null_values = team_possession_stats.isnull().sum()

# Display the count of null values per column
display(null_values)
# Out:
# team          0
# possession    0
# touches       0
# dtype: int64

# %%
standings = pd.read_csv('standings.csv')
display(standings)
# Out:
#     rank             team  win  loss  draw  goals  conceded  points  \
# 0      1        Liverpool   25     4     8     85        40      83
# 1      2          Arsenal   19     4    14     67        33      71
# 2      3  Manchester City   20     9     8     70        44      68
# 3      4    Newcastle Utd   20    11     6     68        46      66
# 4      5          Chelsea   19     9     9     63        43      66
# 5      6      Aston Villa   19     9     9     58        49      66
# 6      7  Nott'ham Forest   19    10     8     58        45      65
# 7      8         Brighton   15     9    13     62        58      58
# 8      9        Brentford   16    14     7     65        56      55
# 9     10           Fulham   15    13     9     54        52      54
# 10    11      Bournemouth   14    12    11     56        46      53
# 11    12   Crystal Palace   13    11    13     50        50      52
# 12    13          Everton   10    12    15     41        44      45
# 13    14           Wolves   12    20     5     53        68      41
# 14    15         West Ham   10    17    10     43        61      40
# 15    16   Manchester Utd   10    18     9     42        54      39
# 16    17        Tottenham   11    21     5     63        61      38
# 17    18   Leicester City    6    24     7     33        78      25
# 18    19     Ipswich Town    4    23    10     35        79      22
# 19    20      Southampton    2    29     6     25        84      12
#
#         last5                      top_scorer             keeper
# 0   W W L D L                   Mohamed Salah            Alisson
# 1   W D L D W                     Kai Havertz         David Raya
# 2   W W W D W                  Erling Haaland            Ederson
# 3   L W D W L                  Alexander Isak          Nick Pope
# 4   W W W L W                     Cole Palmer     Robert Sánchez
# 5   W L W W W                   Ollie Watkins  Emiliano Martínez
# 6   W L D D W                      Chris Wood          Matz Sels
# 7   L W D W W  Kaoru Mitoma, Danny Welbeck...    Bart Verbruggen
# 8   W W W W L       Yoane Wissa, Bryan Mbeumo       Mark Flekken
# 9   L W L L W                    Raúl Jiménez         Bernd Leno
# 10  D D W L L                 Justin Kluivert  Kepa Arrizabalaga
# 11  D D D W W            Jean-Philippe Mateta     Dean Henderson
# 12  L L D W W                   Iliman Ndiaye    Jordan Pickford
# 13  W W L L L                   Matheus Cunha            José Sá
# 14  D L D W L                    Jarrod Bowen    Alphonse Areola
# 15  L D L L L                 Bruno Fernandes        André Onana
# 16  L L D L L                 Brennan Johnson  Guglielmo Vicario
# 17  L L W D W                     Jamie Vardy     Mads Hermansen
# 18  L L D L L                      Liam Delap     Arijanet Muric
# 19  D L L D L                    Paul Onuachu     Aaron Ramsdale

# %%
# Drop the 'last5' column from the standings DataFrame
standings = standings.drop('last5', axis=1)

# Display the updated DataFrame
display(standings)
# Out:
#     rank             team  win  loss  draw  goals  conceded  points  \
# 0      1        Liverpool   25     4     8     85        40      83
# 1      2          Arsenal   19     4    14     67        33      71
# 2      3  Manchester City   20     9     8     70        44      68
# 3      4    Newcastle Utd   20    11     6     68        46      66
# 4      5          Chelsea   19     9     9     63        43      66
# 5      6      Aston Villa   19     9     9     58        49      66
# 6      7  Nott'ham Forest   19    10     8     58        45      65
# 7      8         Brighton   15     9    13     62        58      58
# 8      9        Brentford   16    14     7     65        56      55
# 9     10           Fulham   15    13     9     54        52      54
# 10    11      Bournemouth   14    12    11     56        46      53
# 11    12   Crystal Palace   13    11    13     50        50      52
# 12    13          Everton   10    12    15     41        44      45
# 13    14           Wolves   12    20     5     53        68      41
# 14    15         West Ham   10    17    10     43        61      40
# 15    16   Manchester Utd   10    18     9     42        54      39
# 16    17        Tottenham   11    21     5     63        61      38
# 17    18   Leicester City    6    24     7     33        78      25
# 18    19     Ipswich Town    4    23    10     35        79      22
# 19    20      Southampton    2    29     6     25        84      12
#
#                         top_scorer             keeper
# 0                    Mohamed Salah            Alisson
# 1                      Kai Havertz         David Raya
# 2                   Erling Haaland            Ederson
# 3                   Alexander Isak          Nick Pope
# 4                      Cole Palmer     Robert Sánchez
# 5                    Ollie Watkins  Emiliano Martínez
# 6                       Chris Wood          Matz Sels
# 7   Kaoru Mitoma, Danny Welbeck...    Bart Verbruggen
# 8        Yoane Wissa, Bryan Mbeumo       Mark Flekken
# 9                     Raúl Jiménez         Bernd Leno
# 10                 Justin Kluivert  Kepa Arrizabalaga
# 11            Jean-Philippe Mateta     Dean Henderson
# 12                   Iliman Ndiaye    Jordan Pickford
# 13                   Matheus Cunha            José Sá
# 14                    Jarrod Bowen    Alphonse Areola
# 15                 Bruno Fernandes        André Onana
# 16                 Brennan Johnson  Guglielmo Vicario
# 17                     Jamie Vardy     Mads Hermansen
# 18                      Liam Delap     Arijanet Muric
# 19                    Paul Onuachu     Aaron Ramsdale

# %%
standings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        20 non-null     int64
#  1   team        20 non-null     object
#  2   win         20 non-null     int64
#  3   loss        20 non-null     int64
#  4   draw        20 non-null     int64
#  5   goals       20 non-null     int64
#  6   conceded    20 non-null     int64
#  7   points      20 non-null     int64
#  8   top_scorer  20 non-null     object
#  9   keeper      20 non-null     object
# dtypes: int64(7), object(3)
# memory usage: 1.7+ KB

# %%
player_stats = pd.read_csv('player_stats.csv')
display(player_stats)
# Out:
#                     name         nation position            team   age  \
# 0             Max Aarons        England       DF     Bournemouth  25.0
# 1      Joshua Acheampong        England       DF         Chelsea  19.0
# 2            Tyler Adams  United States       MF     Bournemouth  26.0
# 3       Tosin Adarabioyo        England       DF         Chelsea  27.0
# 4          Simon Adingra   Cote dIvoire    FW,MF        Brighton  23.0
# ..                   ...            ...      ...             ...   ...
# 566         Ashley Young        England       DF         Everton  39.0
# 567       Illia Zabarnyi        Ukraine       DF     Bournemouth  22.0
# 568  Oleksandr Zinchenko        Ukraine    DF,MF         Arsenal  28.0
# 569       Joshua Zirkzee    Netherlands    FW,MF  Manchester Utd  24.0
# 570      Martin Ødegaard         Norway       MF         Arsenal  26.0
#
#        born  played  starts  minutes  goals  assists  penalty_kicks  \
# 0    2000.0       3       1       86      0        0              0
# 1    2006.0       4       2      170      0        0              0
# 2    1999.0      27      20     1875      0        3              0
# 3    1997.0      21      14     1319      1        1              0
# 4    2002.0      28      11     1052      2        2              0
# ..      ...     ...     ...      ...    ...      ...            ...
# 566  1985.0      31      18     1785      1        3              0
# 567  2002.0      35      34     3019      0        0              0
# 568  1996.0      14       4      458      0        1              0
# 569  2001.0      32      14     1402      3        1              0
# 570  1998.0      29      26     2309      2        8              1
#
#      penalty_kick_attempts  yellow  red  expected_goals  progressive_carries  \
# 0                        0       0    0             0.0                    1
# 1                        0       1    0             0.2                    0
# 2                        0       7    0             1.6                   13
# 3                        0       3    0             0.9                    5
# 4                        0       0    0             2.4                   50
# ..                     ...     ...  ...             ...                  ...
# 566                      0       6    1             0.3                   23
# 567                      0       4    1             1.1                   26
# 568                      0       1    0             0.3                   10
# 569                      0       2    0             4.8                   14
# 570                      1       4    0             4.7                   91
#
#      progressive_passes  received_progressive_passes
# 0                     8                            3
# 1                     8                            0
# 2                    71                           10
# 3                    39                            1
# 4                    18                          128
# ..                  ...                          ...
# 566                  89                           32
# 567                 134                            4
# 568                  37                           12
# 569                  44                           69
# 570                 255                          151
#
# [571 rows x 19 columns]

# %%
# Check for null values in each column
null_values = player_stats.isnull().sum()

# Display the count of null values per column
display(null_values)
# Out:
# name                           0
# nation                         3
# position                       0
# team                           0
# age                            3
# born                           3
# played                         0
# starts                         0
# minutes                        0
# goals                          0
# assists                        0
# penalty_kicks                  0
# penalty_kick_attempts          0
# yellow                         0
# red                            0
# expected_goals                 0
# progressive_carries            0
# progressive_passes             0
# received_progressive_passes    0
# dtype: int64

# %%
# Find rows where the 'nation' column is null in player_stats
null_nation_rows = player_stats[player_stats['nation'].isnull()]

# Display the rows with null values in 'nation'
display(null_nation_rows)
# Out:
#              name nation position            team  age  born  played  starts  \
# 169    Jake Evans    NaN       FW  Leicester City  NaN   NaN       3       0
# 324   Mateus Mane    NaN       MF          Wolves  NaN   NaN       1       0
# 356  Jeremy Monga    NaN    FW,MF  Leicester City  NaN   NaN       6       0
#
#      minutes  goals  assists  penalty_kicks  penalty_kick_attempts  yellow  \
# 169       19      0        0              0                      0       0
# 324        2      0        0              0                      0       0
# 356       93      0        0              0                      0       0
#
#      red  expected_goals  progressive_carries  progressive_passes  \
# 169    0             0.0                    0                   0
# 324    0             0.0                    0                   0
# 356    0             0.2                    6                   3
#
#      received_progressive_passes
# 169                            1
# 324                            0
# 356                           10

# %%
# Get the number of unique values in the 'position' column
num_unique_positions = player_stats['position'].nunique()

# Display the result
print(f"Hay {num_unique_positions} tipos de posiciones únicas en el DataFrame.")
# Out:
# Hay 10 tipos de posiciones únicas en el DataFrame.

# %%
# Get the unique values in the 'position' column
unique_positions = player_stats['position'].unique()

# Display the unique positions
print("Los tipos de posiciones únicas son:")
for position in unique_positions:
    print(position)
# Out:
# Los tipos de posiciones únicas son:
# DF
# MF
# FW,MF
# GK
# FW
# FW,DF
# DF,MF
# MF,DF
# MF,FW
# DF,FW

# %%
# Fill null values in the 'nation' column with 'England' for the identified rows
player_stats.loc[player_stats['nation'].isnull(), 'nation'] = 'England'

# Verify the changes by displaying the rows that previously had nulls in 'nation'
display(player_stats.loc[null_nation_rows.index])
# Out:
#              name   nation position            team  age  born  played  \
# 169    Jake Evans  England       FW  Leicester City  NaN   NaN       3
# 324   Mateus Mane  England       MF          Wolves  NaN   NaN       1
# 356  Jeremy Monga  England    FW,MF  Leicester City  NaN   NaN       6
#
#      starts  minutes  goals  assists  penalty_kicks  penalty_kick_attempts  \
# 169       0       19      0        0              0                      0
# 324       0        2      0        0              0                      0
# 356       0       93      0        0              0                      0
#
#      yellow  red  expected_goals  progressive_carries  progressive_passes  \
# 169       0    0             0.0                    0                   0
# 324       0    0             0.0                    0                   0
# 356       0    0             0.2                    6                   3
#
#      received_progressive_passes
# 169                            1
# 324                            0
# 356                           10

# %%
# Find the row for Jeremy Monga
jeremy_monga_row_index = player_stats[player_stats['Name'] == 'Jeremy Monga'].index

# Update the 'born' and 'age' values for Jeremy Monga
player_stats.loc[jeremy_monga_row_index, 'born'] = 2009
player_stats.loc[jeremy_monga_row_index, 'age'] = 15

# Display the updated row for verification
display(player_stats.loc[jeremy_monga_row_index])
# Out:
#              name   nation position            team   age    born  played  \
# 356  Jeremy Monga  England    FW,MF  Leicester City  15.0  2009.0       6
#
#      starts  minutes  goals  assists  penalty_kicks  penalty_kick_attempts  \
# 356       0       93      0        0              0                      0
#
#      yellow  red  expected_goals  progressive_carries  progressive_passes  \
# 356       0    0             0.2                    6                   3
#
#      received_progressive_passes
# 356                           10

# %%
# Find the row for Mateus Mane
mateus_mane_row_index = player_stats[player_stats['Name'] == 'Mateus Mane'].index

# Update the 'born' and 'age' values for Mateus Mane
player_stats.loc[mateus_mane_row_index, 'born'] = 2007
player_stats.loc[mateus_mane_row_index, 'age'] = 17

# Display the updated row for verification
display(player_stats.loc[mateus_mane_row_index])
# Out:
#             name   nation position    team   age    born  played  starts  \
# 324  Mateus Mane  England       MF  Wolves  17.0  2007.0       1       0
#
#      minutes  goals  assists  penalty_kicks  penalty_kick_attempts  yellow  \
# 324        2      0        0              0                      0       0
#
#      red  expected_goals  progressive_carries  progressive_passes  \
# 324    0             0.0                    0                   0
#
#      received_progressive_passes
# 324                            0

# %%
# Find the row for Jake Evans
jake_evans_row_index = player_stats[player_stats['Name'] == 'Jake Evans'].index

# Update the 'born' and 'age' values for Jake Evans
player_stats.loc[jake_evans_row_index, 'born'] = 2008
player_stats.loc[jake_evans_row_index, 'age'] = 17

# Display the updated row for verification
display(player_stats.loc[jake_evans_row_index])
# Out:
#            name   nation position            team   age    born  played  \
# 169  Jake Evans  England       FW  Leicester City  17.0  2008.0       3
#
#      starts  minutes  goals  assists  penalty_kicks  penalty_kick_attempts  \
# 169       0       19      0        0              0                      0
#
#      yellow  red  expected_goals  progressive_carries  progressive_passes  \
# 169       0    0             0.0                    0                   0
#
#      received_progressive_passes
# 169                            1

# %%
# Check for null values in each column
null_values_after_update = player_stats.isnull().sum()

# Display the count of null values per column
display(null_values_after_update)
# Out:
# name                           0
# nation                         0
# position                       0
# team                           0
# age                            0
# born                           0
# played                         0
# starts                         0
# minutes                        0
# goals                          0
# assists                        0
# penalty_kicks                  0
# penalty_kick_attempts          0
# yellow                         0
# red                            0
# expected_goals                 0
# progressive_carries            0
# progressive_passes             0
# received_progressive_passes    0
# dtype: int64

# %%
player_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         571 non-null    object
#  1   nation                       571 non-null    object
#  2   position                     571 non-null    object
#  3   team                         571 non-null    object
#  4   age                          571 non-null    float64
#  5   born                         571 non-null    float64
#  6   played                       571 non-null    int64
#  7   starts                       571 non-null    int64
#  8   minutes                      571 non-null    int64
#  9   goals                        571 non-null    int64
#  10  assists                      571 non-null    int64
#  11  penalty_kicks                571 non-null    int64
#  12  penalty_kick_attempts        571 non-null    int64
#  13  yellow                       571 non-null    int64
#  14  red                          571 non-null    int64
#  15  expected_goals               571 non-null    float64
#  16  progressive_carries          571 non-null    int64
#  17  progressive_passes           571 non-null    int64
#  18  received_progressive_passes  571 non-null    int64
# dtypes: float64(3), int64(12), object(4)
# memory usage: 84.9+ KB

# %%
# Convert 'age' and 'born' columns to int64
player_stats['age'] = player_stats['age'].astype(int)
player_stats['born'] = player_stats['born'].astype(int)

# Verify the data types
player_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         571 non-null    object
#  1   nation                       571 non-null    object
#  2   position                     571 non-null    object
#  3   team                         571 non-null    object
#  4   age                          571 non-null    int64
#  5   born                         571 non-null    int64
#  6   played                       571 non-null    int64
#  7   starts                       571 non-null    int64
#  8   minutes                      571 non-null    int64
#  9   goals                        571 non-null    int64
#  10  assists                      571 non-null    int64
#  11  penalty_kicks                571 non-null    int64
#  12  penalty_kick_attempts        571 non-null    int64
#  13  yellow                       571 non-null    int64
#  14  red                          571 non-null    int64
#  15  expected_goals               571 non-null    float64
#  16  progressive_carries          571 non-null    int64
#  17  progressive_passes           571 non-null    int64
#  18  received_progressive_passes  571 non-null    int64
# dtypes: float64(1), int64(14), object(4)
# memory usage: 84.9+ KB

# %%
display(player_stats)
# Out:
#                     name         nation position            team  age  born  \
# 0             Max Aarons        England       DF     Bournemouth   25  2000
# 1      Joshua Acheampong        England       DF         Chelsea   19  2006
# 2            Tyler Adams  United States       MF     Bournemouth   26  1999
# 3       Tosin Adarabioyo        England       DF         Chelsea   27  1997
# 4          Simon Adingra   Cote dIvoire    FW,MF        Brighton   23  2002
# ..                   ...            ...      ...             ...  ...   ...
# 566         Ashley Young        England       DF         Everton   39  1985
# 567       Illia Zabarnyi        Ukraine       DF     Bournemouth   22  2002
# 568  Oleksandr Zinchenko        Ukraine    DF,MF         Arsenal   28  1996
# 569       Joshua Zirkzee    Netherlands    FW,MF  Manchester Utd   24  2001
# 570      Martin Ødegaard         Norway       MF         Arsenal   26  1998
#
#      played  starts  minutes  goals  assists  penalty_kicks  \
# 0         3       1       86      0        0              0
# 1         4       2      170      0        0              0
# 2        27      20     1875      0        3              0
# 3        21      14     1319      1        1              0
# 4        28      11     1052      2        2              0
# ..      ...     ...      ...    ...      ...            ...
# 566      31      18     1785      1        3              0
# 567      35      34     3019      0        0              0
# 568      14       4      458      0        1              0
# 569      32      14     1402      3        1              0
# 570      29      26     2309      2        8              1
#
#      penalty_kick_attempts  yellow  red  expected_goals  progressive_carries  \
# 0                        0       0    0             0.0                    1
# 1                        0       1    0             0.2                    0
# 2                        0       7    0             1.6                   13
# 3                        0       3    0             0.9                    5
# 4                        0       0    0             2.4                   50
# ..                     ...     ...  ...             ...                  ...
# 566                      0       6    1             0.3                   23
# 567                      0       4    1             1.1                   26
# 568                      0       1    0             0.3                   10
# 569                      0       2    0             4.8                   14
# 570                      1       4    0             4.7                   91
#
#      progressive_passes  received_progressive_passes
# 0                     8                            3
# 1                     8                            0
# 2                    71                           10
# 3                    39                            1
# 4                    18                          128
# ..                  ...                          ...
# 566                  89                           32
# 567                 134                            4
# 568                  37                           12
# 569                  44                           69
# 570                 255                          151
#
# [571 rows x 19 columns]

# %%
player_salaries = pd.read_csv('player_salaries.csv')
display(player_salaries)
# Out:
#                 Player Nation Position             Team  Age  Weekly    Annual
# 0      Kevin De Bruyne    BEL    MF,FW  Manchester City   33  488501  25402046
# 1       Erling Haaland    NOR       FW  Manchester City   24  457970  23814418
# 2             Casemiro    BRA       MF   Manchester Utd   32  427438  22226790
# 3        Mohamed Salah    EGY       FW        Liverpool   32  427438  22226790
# 4      Bruno Fernandes    POR       MF   Manchester Utd   29  366376  19051534
# ..                 ...    ...      ...              ...  ...     ...       ...
# 679  Cameron Humphreys    NaN       CM     Ipswich Town   21    1309     68072
# 680      George Abbott    NaN       DM        Tottenham   19    1007     52356
# 681      Rico Richards    ENG       AM      Aston Villa   21    1007     52356
# 682        Kobei Moore    NaN       CF      Aston Villa   20     805     41885
# 683    Luca Stephenson    NaN       DM        Liverpool   21     537     27923
#
# [684 rows x 7 columns]

# %%
display(player_salaries)
# Out:
#                 Player Position             Team  Age  Weekly    Annual
# 0      Kevin De Bruyne    MF,FW  Manchester City   33  488501  25402046
# 1       Erling Haaland       FW  Manchester City   24  457970  23814418
# 2             Casemiro       MF   Manchester Utd   32  427438  22226790
# 3        Mohamed Salah       FW        Liverpool   32  427438  22226790
# 4      Bruno Fernandes       MF   Manchester Utd   29  366376  19051534
# ..                 ...      ...              ...  ...     ...       ...
# 679  Cameron Humphreys       CM     Ipswich Town   21    1309     68072
# 680      George Abbott       DM        Tottenham   19    1007     52356
# 681      Rico Richards       AM      Aston Villa   21    1007     52356
# 682        Kobei Moore       CF      Aston Villa   20     805     41885
# 683    Luca Stephenson       DM        Liverpool   21     537     27923
#
# [684 rows x 6 columns]

# %%
player_possession_stats = pd.read_csv('player_possession_stats.csv')
display(player_possession_stats)
# Out:
#                   player nation position            team   age   90s  touches  \
# 0             Max Aarons    ENG       DF     Bournemouth  25.0   1.0       73
# 1      Joshua Acheampong    ENG       DF         Chelsea  19.0   1.9      137
# 2            Tyler Adams    USA       MF     Bournemouth  26.0  20.8     1279
# 3       Tosin Adarabioyo    ENG       DF         Chelsea  27.0  14.7     1255
# 4          Simon Adingra    CIV    FW,MF        Brighton  23.0  11.7      529
# ..                   ...    ...      ...             ...   ...   ...      ...
# 566         Ashley Young    ENG       DF         Everton  39.0  19.8     1154
# 567       Illia Zabarnyi    UKR       DF     Bournemouth  22.0  33.5     1985
# 568  Oleksandr Zinchenko    UKR    DF,MF         Arsenal  28.0   5.1      413
# 569       Joshua Zirkzee    NED    FW,MF  Manchester Utd  24.0  15.6      587
# 570     Martin Ãdegaard    NOR       MF         Arsenal  26.0  25.7     1674
#
#      deffensive_touches  middle_touches  attacking_touches  \
# 0                    19              40                 15
# 1                    48              81                  8
# 2                   338             741                214
# 3                   596             633                 27
# 4                    66             168                302
# ..                  ...             ...                ...
# 566                 354             507                300
# 567                 908            1026                 73
# 568                  77             207                130
# 569                  71             303                219
# 570                 125             705                859
#
#      attempted_take_ons  successful_take_ons  takeons_tackled  carries  \
# 0                     2                    0                1       41
# 1                     2                    1                0      106
# 2                    17                    3               10      622
# 3                     5                    4                0      733
# 4                    49                   21               27      356
# ..                  ...                  ...              ...      ...
# 566                  18                    5                9      473
# 567                   8                    5                2     1221
# 568                   4                    3                0      235
# 569                  35                   11               24      327
# 570                  58                   24               32     1158
#
#      total_distance_carried  received
# 0                       152        40
# 1                       709       111
# 2                      3119       718
# 3                      2991       948
# 4                      2460       372
# ..                      ...       ...
# 566                    2375       602
# 567                    7951      1246
# 568                    1151       287
# 569                    1483       418
# 570                    7365      1318
#
# [571 rows x 16 columns]

# %%
# Drop the specified columns from player_possession_stats
columns_to_drop = ['nation', 'position', 'age', '90s', 'deffensive_touches', 'middle_touches', 'attacking_touches']
player_possession_stats = player_possession_stats.drop(columns=columns_to_drop)

# Display the first few rows of the updated DataFrame
display(player_possession_stats.head())
# Out:
#               player         team  touches  attempted_take_ons  \
# 0         Max Aarons  Bournemouth       73                   2
# 1  Joshua Acheampong      Chelsea      137                   2
# 2        Tyler Adams  Bournemouth     1279                  17
# 3   Tosin Adarabioyo      Chelsea     1255                   5
# 4      Simon Adingra     Brighton      529                  49
#
#    successful_take_ons  takeons_tackled  carries  total_distance_carried  \
# 0                    0                1       41                     152
# 1                    1                0      106                     709
# 2                    3               10      622                    3119
# 3                    4                0      733                    2991
# 4                   21               27      356                    2460
#
#    received
# 0        40
# 1       111
# 2       718
# 3       948
# 4       372

# %%
# Check for null values in each column
null_values_possession = player_possession_stats.isnull().sum()

# Display the count of null values per column
display(null_values_possession)
# Out:
# player                    0
# team                      0
# touches                   0
# attempted_take_ons        0
# successful_take_ons       0
# takeons_tackled           0
# carries                   0
# total_distance_carried    0
# received                  0
# dtype: int64

# %%
# Save each DataFrame to a CSV file

# Team DataFrames
team_stats.to_csv('team_stats_cleaned.csv', index=False)
team_salary.to_csv('team_salary_cleaned.csv', index=False)
team_possession_stats.to_csv('team_possession_stats_cleaned.csv', index=False)
standings.to_csv('standings_cleaned.csv', index=False)

# Player DataFrames
player_stats.to_csv('player_stats_cleaned.csv', index=False)
player_salaries.to_csv('player_salaries_cleaned.csv', index=False)

print("Todos los DataFrames han sido guardados como archivos CSV en su entorno de Colab.")
print("Puedes descargarlos desde el explorador de archivos (el ícono de carpeta a la izquierda).")
# Out:
# Todos los DataFrames han sido guardados como archivos CSV en su entorno de Colab.
# Puedes descargarlos desde el explorador de archivos (el ícono de carpeta a la izquierda).

# %%
# Save each DataFrame to a CSV file

# Team DataFrames
team_stats.to_csv('team_stats_cleaned.csv', index=False)
team_salary.to_csv('team_salary_cleaned.csv', index=False)
team_possession_stats.to_csv('team_possession_stats_cleaned.csv', index=False)
standings.to_csv('standings_cleaned.csv', index=False)

# Player DataFrames
player_stats.to_csv('player_stats_cleaned.csv', index=False)
player_salaries.to_csv('player_salaries_cleaned.csv', index=False)
player_possession_stats.to_csv('player_possession_stats_cleaned.csv', index=False)

print("Todos los DataFrames han sido guardados como archivos CSV en su entorno de Colab.")
print("Puedes descargarlos desde el explorador de archivos (el ícono de carpeta a la izquierda).")
# Out:
# Todos los DataFrames han sido guardados como archivos CSV en su entorno de Colab.
# Puedes descargarlos desde el explorador de archivos (el ícono de carpeta a la izquierda).
